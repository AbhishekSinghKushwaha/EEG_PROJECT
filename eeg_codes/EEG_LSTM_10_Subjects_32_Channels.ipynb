# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import os

# %%
# !pip install pyedflib
# Out:
# Requirement already satisfied: pyedflib in c:\users\akhileshsing2024\appdata\local\anaconda3\lib\site-packages (0.1.38)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\akhileshsing2024\appdata\local\anaconda3\lib\site-packages (from pyedflib) (1.26.4)

# %%
import pyedflib
import numpy as np

def _read_py_function(filename, num_channels=32):
    # Open the EDF file
    f = pyedflib.EdfReader(filename)
    
    # Get the number of channels and the signal labels
    n_channels = f.signals_in_file
    print(f"Total channels in file: {n_channels}")
    
    # Ensure that we are fetching only the desired number of channels (16 in this case)
    if num_channels > n_channels:
        raise ValueError(f"The file contains only {n_channels} channels, but {num_channels} were requested.")
    
    # Initialize eeg_data to store only the first `num_channels`
    eeg_data = np.zeros((num_channels, f.getNSamples()[0]), dtype=np.float32)
    
    # Read only the first `num_channels` channels
    for i in range(num_channels):
        eeg_data[i, :] = f.readSignal(i)

    n_samples = f.getNSamples()[0]
    reminder = int(n_samples % 160)
    
    # Print statement to check values
    print(f"Original n_samples: {n_samples}")
    print(f"Reminder: {reminder}")
    
    n_samples -= reminder
    seconds = int(n_samples / 160)
    
    # Extract person_id from the filename
    path = filename.split("\\")
    person_id = int(path[-1].partition("S")[2].partition("R")[0])
    
    # Create one-hot encoded labels
    label = np.zeros(10, dtype=bool)
    label[person_id-1] = 1
    labels = np.tile(label, (seconds, 1))
    
    # Normalization step
    for i in range(num_channels):
        channel_data = eeg_data[i, :]
        mean_i = np.mean(channel_data)  # Compute mean of channel i
        std_i = np.std(channel_data)    # Compute standard deviation of channel i
        
        if std_i != 0:  # Avoid division by zero
            eeg_data[i, :] = (channel_data - mean_i) / std_i  # Normalize channel i

    # Transpose the data to shape (n_samples, n_channels)
    eeg_data = eeg_data.T
    
    if reminder > 0:
        eeg_data = eeg_data[:-reminder, :]
    
    # Split the data into 160-sample chunks
    intervals = np.linspace(0, n_samples, num=seconds, endpoint=False, dtype=int)
    eeg_data = np.split(eeg_data, intervals)
    del eeg_data[0]
    eeg_data = np.array(eeg_data)
    
    return eeg_data, labels

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

def load_eeg_data_with_pyedflib(data_path, max_subjects=10):
    # Initialize the global variables
    global subject_data, all_train_data, all_train_labels, all_test_data, all_test_labels
    global train_data, val_data, train_labels, val_labels

    # Initialize the variables before using them
    subject_data = {}
    all_train_data = []
    all_train_labels = []
    all_test_data = []
    all_test_labels = []

    subject_count = 0  # Counter to track the number of subjects processed

    for subject_dir in os.listdir(data_path):
        subject_path = os.path.join(data_path, subject_dir)
        if os.path.isdir(subject_path):
            print(f"Processing subject: {subject_dir}")
            subject_data[subject_dir] = {}
            for recording_file in os.listdir(subject_path):
                recording_path = os.path.join(subject_path, recording_file)
                if recording_file.endswith('.edf'):
                    recording_id = os.path.splitext(recording_file)[0]
                    print(f"Loading recording: {recording_file}")

                    try:
                        #eeg_data, labels = _read_py_function(recording_path)
                        eeg_data, labels = _read_py_function(recording_path)

                        print(f"Data shape after processing: {eeg_data.shape}")
                        print(f"Labels shape: {labels.shape}")

                        train_data, test_data, train_labels, test_labels = train_test_split(
                            eeg_data, labels, test_size=0.1, random_state=42
                        )
                        
                        all_train_data.append(train_data)
                        all_train_labels.append(train_labels)
                        all_test_data.append(test_data)
                        all_test_labels.append(test_labels)

                    except Exception as e:
                        print(f"Error loading {recording_file}: {e}")

            subject_count += 1  # Increment the subject counter

            # Stop processing once the desired number of subjects is reached
            if subject_count >= max_subjects:
                print(f"Processed {max_subjects} subjects. Stopping further processing.")
                break

    print(f"Train data list length: {len(all_train_data)}")
    print(f"Train labels list length: {len(all_train_labels)}")
    print(f"Test data list length: {len(all_test_data)}")
    print(f"Test labels list length: {len(all_test_labels)}")

    if all_train_data and all_train_labels:
        all_train_data = np.concatenate(all_train_data, axis=0)
        all_train_labels = np.concatenate(all_train_labels, axis=0)
    else:
        print("No training data loaded.")
        return None, None, None, None, None, None

    if all_test_data and all_test_labels:
        all_test_data = np.concatenate(all_test_data, axis=0)
        all_test_labels = np.concatenate(all_test_labels, axis=0)
    else:
        print("No test data loaded.")
        return None, None, None, None, None, None

    if len(all_train_data) == 0 or len(all_train_labels) == 0:
        print("No data available for splitting into training and validation sets.")
        return None, None, None, None, None, None

    # Split train data further into training and validation sets
    train_data, val_data, train_labels, val_labels = train_test_split(
        all_train_data, all_train_labels, test_size=0.25, random_state=42
    )

    return train_data, train_labels, val_data, val_labels, all_test_data, all_test_labels

# %%
data_path = r"C:\Users\akhileshsing2024\Downloads\eeg-motor-movementimagery-dataset-1.0.0\files"
train_data, train_labels, val_data, val_labels, test_data, test_labels = load_eeg_data_with_pyedflib(data_path)
# Access global variables directly if needed
print(f"Train data shape: {train_data.shape if train_data is not None else 'None'}")
print(f"Validation data shape: {val_data.shape if val_data is not None else 'None'}")
print(f"Test data shape: {test_data.shape if test_data is not None else 'None'}")
# Out:
# Processing subject: S001
# Loading recording: S001R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S001R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S001R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R11.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R12.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R13.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S001R14.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Processing subject: S002
# Loading recording: S002R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S002R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S002R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S002R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Processing subject: S003
# Loading recording: S003R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S003R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S003R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R11.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R12.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R13.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S003R14.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Processing subject: S004
# Loading recording: S004R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S004R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S004R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S004R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Processing subject: S005
# Loading recording: S005R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S005R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S005R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S005R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Processing subject: S006
# Loading recording: S006R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S006R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S006R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S006R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Processing subject: S007
# Loading recording: S007R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S007R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S007R03.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R04.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R05.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R06.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R07.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R08.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R09.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R10.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R11.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R12.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R13.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Loading recording: S007R14.edf
# Total channels in file: 64
# Original n_samples: 20000
# Reminder: 0
# Data shape after processing: (125, 160, 32)
# Labels shape: (125, 10)
# Processing subject: S008
# Loading recording: S008R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S008R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S008R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S008R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Processing subject: S009
# Loading recording: S009R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S009R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S009R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S009R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Processing subject: S010
# Loading recording: S010R01.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S010R02.edf
# Total channels in file: 64
# Original n_samples: 9760
# Reminder: 0
# Data shape after processing: (61, 160, 32)
# Labels shape: (61, 10)
# Loading recording: S010R03.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R04.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R05.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R06.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R07.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R08.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R09.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R10.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R11.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R12.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R13.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Loading recording: S010R14.edf
# Total channels in file: 64
# Original n_samples: 19680
# Reminder: 0
# Data shape after processing: (123, 160, 32)
# Labels shape: (123, 10)
# Processed 10 subjects. Stopping further processing.
# Train data list length: 140
# Train labels list length: 140
# Test data list length: 140
# Test labels list length: 140
# Train data shape: (10764, 160, 32)
# Validation data shape: (3588, 160, 32)
# Test data shape: (1700, 160, 32)

# %%
import tensorflow as tf

def eeg_biometric_identification_model_lstm(input_shape, n_classes, lstm_size=192, keep_prob=0.5):
    inputs = tf.keras.Input(shape=input_shape)

    # Initial LSTM Layers for feature extraction (replacing Conv1D layers)
    lstm1 = tf.keras.layers.LSTM(units=128, return_sequences=True)(inputs)  # First LSTM layer
    lstm2 = tf.keras.layers.LSTM(units=256, return_sequences=True)(lstm1)   # Second LSTM layer
    lstm3 = tf.keras.layers.LSTM(units=512, return_sequences=True)(lstm2)   # Third LSTM layer
    lstm4 = tf.keras.layers.LSTM(units=1024, return_sequences=False)(lstm3) # Fourth LSTM layer

    # Fully connected layer with 192 neurons and dropout
    fc1 = tf.keras.layers.Dense(units=192, activation='relu')(lstm4)
    dropout_fc1 = tf.keras.layers.Dropout(rate=1 - keep_prob)(fc1)

    # Reshape to (batch_size, timesteps=1, features=192) for additional LSTM layers
    lstm_input = tf.keras.layers.Reshape((1, 192))(dropout_fc1)

    # Add the two specific LSTM layers from the original architecture
    lstm_out = tf.keras.layers.LSTM(units=lstm_size, return_sequences=True)(lstm_input)  # First LSTM layer
    lstm_out = tf.keras.layers.LSTM(units=lstm_size, return_sequences=False)(lstm_out)  # Second LSTM layer

    # Fully connected layers after LSTM
    fc2 = tf.keras.layers.Dense(units=192, activation='relu')(lstm_out)
    fc3 = tf.keras.layers.Dense(units=192, activation='relu')(fc2)

    # Output layer (Softmax for classification)
    output = tf.keras.layers.Dense(n_classes, activation='softmax')(fc3)

    # Create the model
    model = tf.keras.Model(inputs=inputs, outputs=output)

    return model

# Example usage
input_shape = (160, 32)  # 160 samples, 64 channels (1-second EEG recording)
n_classes = 10  # Number of subjects
keep_prob = 0.5  # Dropout rate

model = eeg_biometric_identification_model_lstm(input_shape, n_classes, lstm_size=192, keep_prob=keep_prob)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 160, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 160, 128)       │        82,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 160, 256)       │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 160, 512)       │     1,574,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 1024)           │     6,295,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 192)            │       196,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 192)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 1, 192)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 1, 192)         │       295,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 192)            │       295,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 192)            │        37,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 192)            │        37,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,930 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,211,338 (35.14 MB)
#  Trainable params: 9,211,338 (35.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_path = "C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5"  # Save the best model in the current directory
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,  # Save only the best model
                                                 monitor='val_loss',  # Monitor validation loss
                                                 mode='min',  # Save the model with the lowest validation loss
                                                 verbose=1)

# Training the model
with tf.device('/GPU:0'):  # Ensure training uses the GPU
    history = model.fit(train_data, train_labels, 
                        epochs=20, 
                        validation_data=(val_data, val_labels), 
                        batch_size=80,  
                        callbacks=[cp_callback])
# Out:
# Epoch 1/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1204 - loss: 2.2868
# Epoch 1: val_loss improved from inf to 1.96039, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 913s 6s/step - accuracy: 0.1206 - loss: 2.2863 - val_accuracy: 0.1809 - val_loss: 1.9604
# Epoch 2/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2041 - loss: 1.9025
# Epoch 2: val_loss improved from 1.96039 to 1.76361, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 866s 6s/step - accuracy: 0.2042 - loss: 1.9021 - val_accuracy: 0.2584 - val_loss: 1.7636
# Epoch 3/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2630 - loss: 1.7566
# Epoch 3: val_loss improved from 1.76361 to 1.59719, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 851s 6s/step - accuracy: 0.2630 - loss: 1.7565 - val_accuracy: 0.3113 - val_loss: 1.5972
# Epoch 4/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3390 - loss: 1.5656
# Epoch 4: val_loss improved from 1.59719 to 1.47307, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 755s 6s/step - accuracy: 0.3391 - loss: 1.5654 - val_accuracy: 0.3464 - val_loss: 1.4731
# Epoch 5/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3651 - loss: 1.4799
# Epoch 5: val_loss improved from 1.47307 to 1.23659, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 599s 4s/step - accuracy: 0.3653 - loss: 1.4793 - val_accuracy: 0.4930 - val_loss: 1.2366
# Epoch 6/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4520 - loss: 1.3181
# Epoch 6: val_loss did not improve from 1.23659
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 514s 4s/step - accuracy: 0.4514 - loss: 1.3202 - val_accuracy: 0.1901 - val_loss: 2.1145
# Epoch 7/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2326 - loss: 1.9828
# Epoch 7: val_loss did not improve from 1.23659
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 519s 4s/step - accuracy: 0.2329 - loss: 1.9818 - val_accuracy: 0.3704 - val_loss: 1.5576
# Epoch 8/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3954 - loss: 1.5076
# Epoch 8: val_loss did not improve from 1.23659
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 521s 4s/step - accuracy: 0.3955 - loss: 1.5071 - val_accuracy: 0.4487 - val_loss: 1.2887
# Epoch 9/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4281 - loss: 1.4529
# Epoch 9: val_loss did not improve from 1.23659
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 517s 4s/step - accuracy: 0.4274 - loss: 1.4562 - val_accuracy: 0.1031 - val_loss: 2.3541
# Epoch 10/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1563 - loss: 2.2093
# Epoch 10: val_loss did not improve from 1.23659
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 531s 4s/step - accuracy: 0.1566 - loss: 2.2083 - val_accuracy: 0.2742 - val_loss: 1.8143
# Epoch 11/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3086 - loss: 1.7527
# Epoch 11: val_loss did not improve from 1.23659
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 537s 4s/step - accuracy: 0.3088 - loss: 1.7520 - val_accuracy: 0.4314 - val_loss: 1.3841
# Epoch 12/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4162 - loss: 1.4166
# Epoch 12: val_loss improved from 1.23659 to 1.23377, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 533s 4s/step - accuracy: 0.4163 - loss: 1.4163 - val_accuracy: 0.4830 - val_loss: 1.2338
# Epoch 13/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4635 - loss: 1.2476
# Epoch 13: val_loss improved from 1.23377 to 1.19314, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 537s 4s/step - accuracy: 0.4636 - loss: 1.2474 - val_accuracy: 0.4916 - val_loss: 1.1931
# Epoch 14/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4934 - loss: 1.1511
# Epoch 14: val_loss improved from 1.19314 to 1.17696, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 542s 4s/step - accuracy: 0.4935 - loss: 1.1511 - val_accuracy: 0.4953 - val_loss: 1.1770
# Epoch 15/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5054 - loss: 1.1263
# Epoch 15: val_loss improved from 1.17696 to 1.14977, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 537s 4s/step - accuracy: 0.5054 - loss: 1.1263 - val_accuracy: 0.5106 - val_loss: 1.1498
# Epoch 16/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5197 - loss: 1.1088
# Epoch 16: val_loss improved from 1.14977 to 1.09409, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 524s 4s/step - accuracy: 0.5198 - loss: 1.1087 - val_accuracy: 0.5387 - val_loss: 1.0941
# Epoch 17/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5269 - loss: 1.0781
# Epoch 17: val_loss improved from 1.09409 to 1.05768, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 537s 4s/step - accuracy: 0.5269 - loss: 1.0780 - val_accuracy: 0.5532 - val_loss: 1.0577
# Epoch 18/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5408 - loss: 1.0694
# Epoch 18: val_loss improved from 1.05768 to 1.05614, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 544s 4s/step - accuracy: 0.5408 - loss: 1.0693 - val_accuracy: 0.5279 - val_loss: 1.0561
# Epoch 19/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5576 - loss: 1.0364
# Epoch 19: val_loss improved from 1.05614 to 1.02813, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 524s 4s/step - accuracy: 0.5576 - loss: 1.0364 - val_accuracy: 0.5605 - val_loss: 1.0281
# Epoch 20/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5471 - loss: 1.0336
# Epoch 20: val_loss improved from 1.02813 to 1.02312, saving model to C:/Users/akhileshsing2024/Desktop/Epochs/best_model/LSTM_32_10.weights.h5
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 541s 4s/step - accuracy: 0.5471 - loss: 1.0335 - val_accuracy: 0.5739 - val_loss: 1.0231

# %%
# Save the training history as a numpy file
np.save("history_LSTM_32.npy", history.history)

# Load the training history
history = np.load("history_LSTM_32.npy", allow_pickle=True).item()

# Ensure history is a dictionary
if type(history) is not dict:
    history = history.history

# Find the epoch with the highest validation accuracy
max_value = max(history['val_accuracy'])
print(f"Max Validation Accuracy: {max_value}")

max_index = history['val_accuracy'].index(max_value)
print(f"Best Epoch Index: {max_index}")
print(f"Corresponding Training Accuracy: {history['accuracy'][max_index]}")

# Load the best checkpoint based on validation accuracy
model.load_weights(checkpoint_path)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(x=test_data, y=test_labels)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Max Validation Accuracy: 0.573857307434082
# Best Epoch Index: 19
# Corresponding Training Accuracy: 0.5534188151359558
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 41s 757ms/step - accuracy: 0.5331 - loss: 1.1193
# Test Loss: 1.002406120300293
# Test Accuracy: 0.5770588517189026

# %%
# Plot training and validation accuracy
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.plot(history['accuracy'], label='Training Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
#plt.savefig("accuracy_plot.png")  # Save the accuracy plot
plt.show()

# Plot training and validation loss
plt.figure(figsize=(8, 6))
plt.plot(history['loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
#plt.savefig("loss_plot.png")  # Save the loss plot
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Get the predictions from the model on the test data
predictions = model.predict(test_data)

# Convert the predicted probabilities into class predictions (argmax over class probabilities)
predicted_classes = np.argmax(predictions, axis=1)

# Convert the one-hot encoded test labels back to their original class labels
true_classes = np.argmax(test_labels, axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print confusion matrix
print(f"Confusion Matrix:\n{cm}")

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.arange(n_classes))
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 753ms/step
# Confusion Matrix:
# [[105   8  53   3   0   1   0   0   0   0]
#  [ 38  49   5   2   2  68   0   0   6   0]
#  [ 35   5  80  31   0  11   0   5   1   2]
#  [  3   0  15  49   0   0   0  59   0  44]
#  [  0   0   0   0 170   0   0   0   0   0]
#  [ 15  20   4   0   0 102   1   0  28   0]
#  [  0   0   0   0   0   0 168   0   2   0]
#  [  6   0  16  39   0   0   0  34   0  75]
#  [ 10  11   3   0   0  57   4   0  85   0]
#  [  0   0   1   8   0   0   0  22   0 139]]
